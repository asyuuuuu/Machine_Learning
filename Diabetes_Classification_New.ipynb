# %%
import pandas as pd
df = pd.read_csv('/content/diabetes.csv')

df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
pd.set_option('display.max_columns', None)
df.head(10)
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
# 5            5      116             74              0        0  25.6
# 6            3       78             50             32       88  31.0
# 7           10      115              0              0        0  35.3
# 8            2      197             70             45      543  30.5
# 9            8      125             96              0        0   0.0
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# ...

# %%
import numpy as np
df['BloodPressure'].replace(0, np.nan, inplace =True)
df['BMI'].replace(0, np.nan, inplace =True)
df['Glucose'].replace(0, np.nan, inplace =True)
df['Insulin'].replace(0, np.nan, inplace =True)
df['SkinThickness'].replace(0, np.nan, inplace =True)

# %%
df['BloodPressure'].value_counts()
# Out:
# BloodPressure
# 70.0     57
# 74.0     52
# 78.0     45
# 68.0     45
# 72.0     44
# 64.0     43
# 80.0     40
# 76.0     39
# 60.0     37
# 62.0     34
# 66.0     30
# 82.0     30
# 88.0     25
# 84.0     23
# 90.0     22
# 58.0     21
# 86.0     21
# 50.0     13
# 56.0     12
# 52.0     11
# 54.0     11
# 75.0      8
# 92.0      8
# 65.0      7
# 94.0      6
# 85.0      6
# 48.0      5
# 96.0      4
# 44.0      4
# 98.0      3
# 100.0     3
# 106.0     3
# 110.0     3
# 55.0      2
# 30.0      2
# 104.0     2
# 46.0      2
# 108.0     2
# 61.0      1
# 38.0      1
# 24.0      1
# 122.0     1
# 102.0     1
# 95.0      1
# 40.0      1
# 114.0     1
# Name: count, dtype: int64

# %%
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  763.000000     733.000000     541.000000  394.000000
# mean      3.845052  121.686763      72.405184      29.153420  155.548223
# std       3.369578   30.535641      12.382158      10.476982  118.775855
# min       0.000000   44.000000      24.000000       7.000000   14.000000
# 25%       1.000000   99.000000      64.000000      22.000000   76.250000
# 50%       3.000000  117.000000      72.000000      29.000000  125.000000
# 75%       6.000000  141.000000      80.000000      36.000000  190.000000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  757.000000                768.000000  768.000000  768.000000
# mean    32.457464                  0.471876   33.240885    0.348958
# std      6.924988                  0.331329   11.760232    0.476951
# ...

# %%
df.head(30)
# Out:
#     Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0             6    148.0           72.0           35.0      NaN  33.6
# 1             1     85.0           66.0           29.0      NaN  26.6
# 2             8    183.0           64.0            NaN      NaN  23.3
# 3             1     89.0           66.0           23.0     94.0  28.1
# 4             0    137.0           40.0           35.0    168.0  43.1
# 5             5    116.0           74.0            NaN      NaN  25.6
# 6             3     78.0           50.0           32.0     88.0  31.0
# 7            10    115.0            NaN            NaN      NaN  35.3
# 8             2    197.0           70.0           45.0    543.0  30.5
# 9             8    125.0           96.0            NaN      NaN   NaN
# 10            4    110.0           92.0            NaN      NaN  37.6
# 11           10    168.0           74.0            NaN      NaN  38.0
# ...

# %%
df.isnull().sum()
# Out:
# Pregnancies                   0
# Glucose                       5
# BloodPressure                35
# SkinThickness               227
# Insulin                     374
# BMI                          11
# DiabetesPedigreeFunction      0
# Age                           0
# Outcome                       0
# dtype: int64

# %%
mean_Glucose= df['Glucose'].astype(float).mean()

df['Glucose'].replace(np.nan, mean_Glucose, inplace = True)

# %%
mean_BP= df['BloodPressure'].mean()
mean_ST= df['SkinThickness'].mean()
mean_BMI= df['BMI'].mean()
mean_Insulin= df['Insulin'].mean()

df['BloodPressure'].replace(np.nan, mean_BP, inplace = True)
df['SkinThickness'].replace(np.nan, mean_ST, inplace = True)
df['BMI'].replace(np.nan, mean_BMI, inplace = True)
df['Insulin'].replace(np.nan, mean_Insulin, inplace = True)

# %%
df.head(30)
# Out:
#     Pregnancies  Glucose  BloodPressure  SkinThickness     Insulin        BMI  \
# 0             6    148.0      72.000000       35.00000  155.548223  33.600000
# 1             1     85.0      66.000000       29.00000  155.548223  26.600000
# 2             8    183.0      64.000000       29.15342  155.548223  23.300000
# 3             1     89.0      66.000000       23.00000   94.000000  28.100000
# 4             0    137.0      40.000000       35.00000  168.000000  43.100000
# 5             5    116.0      74.000000       29.15342  155.548223  25.600000
# 6             3     78.0      50.000000       32.00000   88.000000  31.000000
# 7            10    115.0      72.405184       29.15342  155.548223  35.300000
# 8             2    197.0      70.000000       45.00000  543.000000  30.500000
# 9             8    125.0      96.000000       29.15342  155.548223  32.457464
# 10            4    110.0      92.000000       29.15342  155.548223  37.600000
# ...

# %% [markdown]
# #Model 1

# %%
#define X and y

X= df.drop('Outcome', axis=1)
y= df['Outcome']

# %%
#normalization

import numpy as np
from sklearn import preprocessing
X = preprocessing.StandardScaler().fit_transform(X)
X[:5]
# Out:
# array([[ 6.39947260e-01,  8.65108070e-01, -3.35182392e-02,
#          6.65502121e-01, -3.34507888e-16,  1.66291742e-01,
#          4.68491977e-01,  1.42599540e+00],
#        [-8.44885053e-01, -1.20616153e+00, -5.29859033e-01,
#         -1.74633816e-02, -3.34507888e-16, -8.52531177e-01,
#         -3.65060778e-01, -1.90671905e-01],
#        [ 1.23388019e+00,  2.01581340e+00, -6.95305964e-01,
#          8.08793628e-16, -3.34507888e-16, -1.33283341e+00,
#          6.04397318e-01, -1.05584152e-01],
#        [-8.44885053e-01, -1.07465235e+00, -5.29859033e-01,
#         -7.00428884e-01, -7.24388738e-01, -6.34211980e-01,
#         -9.20762614e-01, -1.04154944e+00],
#        [-1.14185152e+00,  5.03457822e-01, -2.68066914e+00,
#          6.65502121e-01,  1.46550563e-01,  1.54897999e+00,
#          5.48490910e+00, -2.04963989e-02]])

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=30)

print (X_train.shape)
print (X_test.shape)
# Out:
# (576, 8)
# (192, 8)

# %%
#find the best accuracy

import numpy as np
import matplotlib.pyplot as plt
from sklearn import metrics
from sklearn.neighbors import KNeighborsClassifier

Ks =20  #only change this value   #xaxis
mean_acc = np.zeros((Ks-1))
std_acc = np.zeros((Ks-1))
ConfustionMx = [];
for n in range(1,Ks): #volume

    #Train Model and Predict
    neigh = KNeighborsClassifier(n_neighbors = n).fit(X_train,y_train) #n= bassed on value of the neighbour
    yhat=neigh.predict(X_test)
    mean_acc[n-1] = metrics.accuracy_score(y_test, yhat)


    std_acc[n-1]=np.std(yhat==y_test)/np.sqrt(yhat.shape[0])   #value of the accuracy- the y axis

#print (mean_acc) - this is the accuracy value

print ('')
print ('')


#Visualize

plt.plot(range(1,Ks),mean_acc,'g')
plt.fill_between(range(1,Ks),mean_acc - 1 * std_acc,mean_acc + 1 * std_acc, alpha=0.10)
plt.legend(('Accuracy ', '+/- 3xstd'))
plt.ylabel('Accuracy ')
plt.xlabel('The Value of NN (K)')
plt.tight_layout()
plt.show()

print ('')
print ('')

print( "The best accuracy was with", mean_acc.max(), "with k=", mean_acc.argmax()+1)
# Out:
# The best accuracy was with 0.8020833333333334 with k= 18

# %%
#confusion metrics

from sklearn.metrics import classification_report, confusion_matrix

cm = confusion_matrix(y_test, yhat)
print(cm)

print ('TP is ', cm[0][0])
print ('FP is ', cm[0][1])
print ('FN is ', cm[1][0])
print ('TN is ', cm[1][1])
# Out:
# [[113  17]
#  [ 24  38]]
# TP is  113
# FP is  17
# FN is  24
# TN is  38

# %%
#the accuracy of train test should higher than the test

from sklearn.metrics import accuracy_score

print("Test set Accuracy: ", (accuracy_score(y_test, yhat))*100)
print("Train set Accuracy: ", (accuracy_score(y_train, neigh.predict(X_train)))*100)
# Out:
# Test set Accuracy:  78.64583333333334
# Train set Accuracy:  79.86111111111111

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test, yhat))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.87      0.85       130
#            1       0.69      0.61      0.65        62
#
#     accuracy                           0.79       192
#    macro avg       0.76      0.74      0.75       192
# weighted avg       0.78      0.79      0.78       192

# %%
#RBF

from sklearn.svm import SVC

SVM_dia = SVC()

#train
SVM_dia.fit(X_train, y_train)

#predict
y_hat = SVM_dia.predict(X_test)

#evaluation
from sklearn.metrics import accuracy_score

print('The accuracy based on RBF kernel is: ', (accuracy_score(y_test, y_hat))*100)
# Out:
# The accuracy based on RBF kernel is:  76.5625

# %%
#linear

SVM_dia = SVC(kernel='linear')

#train
SVM_dia.fit(X_train, y_train)

#predict
y_hat = SVM_dia.predict(X_test)

#evaluation
from sklearn.metrics import accuracy_score

print('The accuracy based on RBF kernel is: ', (accuracy_score(y_test, y_hat))*100)
# Out:
# The accuracy based on RBF kernel is:  78.125

# %%
#poly

SVM_dia = SVC(kernel='poly')

#train
SVM_dia.fit(X_train, y_train)

#predict
y_hat = SVM_dia.predict(X_test)

#evaluation
from sklearn.metrics import accuracy_score

print('The accuracy based on RBF kernel is: ', (accuracy_score(y_test, y_hat))*100)
# Out:
# The accuracy based on RBF kernel is:  75.0

# %%
#sigmoid

SVM_dia = SVC(kernel='sigmoid')

#train
SVM_dia.fit(X_train, y_train)

#predict
y_hat = SVM_dia.predict(X_test)

#evaluation
from sklearn.metrics import accuracy_score

print('The accuracy based on RBF kernel is: ', (accuracy_score(y_test, y_hat))*100)
# Out:
# The accuracy based on RBF kernel is:  75.52083333333334

# %%
#Decision Tree

from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import jaccard_score

DS = DecisionTreeClassifier()

#training
DS.fit(X_train, y_train)

#prediction
y_hat = DS.predict(X_test)

#evaluation
print('The Accuracy Score is: ', accuracy_score(y_test, y_hat))
print ('')
print('The Confusion Matrix is: ', confusion_matrix(y_test, y_hat))
print ('')
print('The Jaccard Score is: ', jaccard_score(y_test, y_hat, average='micro')) # Change average to 'micro'
# Out:
# The Accuracy Score is:  0.7135416666666666
#
# The Confusion Matrix is:  [[103  27]
#  [ 28  34]]
#
# The Jaccard Score is:  0.5546558704453441

# %%
# prompt: please conclude this analysis

# Conclusion:

# K-Nearest Neighbors (KNN):
# - Achieved a best accuracy of approximately 79% with k=17.
# - This suggests that considering the 17 nearest neighbors provides a good balance between overfitting and underfitting for this dataset.

# Support Vector Machines (SVM):
# - Explored different kernels (RBF, linear, poly, sigmoid).
# - The linear kernel yielded the highest accuracy among SVM variations, but it still fell short of the KNN performance.

# Overall:
# - For this specific diabetes prediction task, KNN with k=17 appears to be the more suitable model based on accuracy.
# - However, further exploration of hyperparameter tuning and feature engineering could potentially improve the performance of both KNN and SVM models.
# - Additionally, considering other evaluation metrics like precision, recall, and F1-score would provide a more comprehensive assessment of model performance, especially in imbalanced datasets.

# %% [markdown]
# #Model 2

# %%
df.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
X1 = df[['BloodPressure', 'BMI', 'Age']].values
y1 = df['Outcome'].values

# %%
#normalization

import numpy as np
from sklearn import preprocessing
X1 = preprocessing.StandardScaler().fit_transform(X)
X1[:5]
# Out:
# array([[ 6.39947260e-01,  8.65108070e-01, -3.35182392e-02,
#          6.65502121e-01, -1.44098110e-18,  1.66291742e-01,
#          4.68491977e-01,  1.42599540e+00],
#        [-8.44885053e-01, -1.20616153e+00, -5.29859033e-01,
#         -1.74633816e-02, -1.44098110e-18, -8.52531177e-01,
#         -3.65060778e-01, -1.90671905e-01],
#        [ 1.23388019e+00,  2.01581340e+00, -6.95305964e-01,
#          1.31337932e-17, -1.44098110e-18, -1.33283341e+00,
#          6.04397318e-01, -1.05584152e-01],
#        [-8.44885053e-01, -1.07465235e+00, -5.29859033e-01,
#         -7.00428884e-01, -7.24388738e-01, -6.34211980e-01,
#         -9.20762614e-01, -1.04154944e+00],
#        [-1.14185152e+00,  5.03457822e-01, -2.68066914e+00,
#          6.65502121e-01,  1.46550563e-01,  1.54897999e+00,
#          5.48490910e+00, -2.04963989e-02]])

# %%
from sklearn.model_selection import train_test_split
X1_train, X1_test, y1_train, y1_test = train_test_split(X1, y1, test_size=0.25, random_state=42)

print (X1_train.shape)
print (X1_test.shape)
# Out:
# (576, 8)
# (192, 8)

# %%
#find the best accuracy

import numpy as np
import matplotlib.pyplot as plt
from sklearn import metrics
from sklearn.neighbors import KNeighborsClassifier

Ks =10  #only change this value   #xaxis
mean_acc = np.zeros((Ks-1))
std_acc = np.zeros((Ks-1))
ConfustionMx = [];
for n in range(1,Ks): #volume

    #Train Model and Predict
    neigh = KNeighborsClassifier(n_neighbors = n).fit(X1_train,y1_train) #n= bassed on value of the neighbour
    yhat1=neigh.predict(X1_test)
    mean_acc[n-1] = metrics.accuracy_score(y1_test, yhat1)


    std_acc[n-1]=np.std(yhat1==y1_test)/np.sqrt(yhat1.shape[0])   #value of the accuracy- the y axis

#print (mean_acc) - this is the accuracy value

print ('')
print ('')


#Visualize

plt.plot(range(1,Ks),mean_acc,'g')
plt.fill_between(range(1,Ks),mean_acc - 1 * std_acc,mean_acc + 1 * std_acc, alpha=0.10)
plt.legend(('Accuracy ', '+/- 3xstd'))
plt.ylabel('Accuracy ')
plt.xlabel('The Value of NN (K)')
plt.tight_layout()
plt.show()

print ('')
print ('')

print( "The best accuracy was with", mean_acc.max(), "with k=", mean_acc.argmax()+1)
# Out:
# The best accuracy was with 0.7083333333333334 with k= 5

# %%
#confusion metrics

from sklearn.metrics import classification_report, confusion_matrix

cm = confusion_matrix(y1_test, yhat1)
print(cm)

print ('TP is ', cm[0][0])
print ('FP is ', cm[0][1])
print ('FN is ', cm[1][0])
print ('TN is ', cm[1][1])
# Out:
# [[93 30]
#  [29 40]]
# TP is  93
# FP is  30
# FN is  29
# TN is  40

# %%
#the accuracy of train test should higher than the test

from sklearn.metrics import accuracy_score

print("Test set Accuracy: ", (accuracy_score(y1_test, yhat1))*100)
print("Train set Accuracy: ", (accuracy_score(y1_train, neigh.predict(X1_train)))*100)
# Out:
# Test set Accuracy:  69.27083333333334
# Train set Accuracy:  81.25

# %%
from sklearn.metrics import classification_report

print(classification_report(y1_test, yhat1))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.76      0.76      0.76       123
#            1       0.57      0.58      0.58        69
#
#     accuracy                           0.69       192
#    macro avg       0.67      0.67      0.67       192
# weighted avg       0.69      0.69      0.69       192

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import jaccard_score

DS = DecisionTreeClassifier()

#training
DS.fit(X_train, y_train)

#prediction
y_hat = DS.predict(X_test)

#evaluation
print('The Accuracy Score is: ', accuracy_score(y_test, y_hat))
print ('')
print('The Confusion Matrix is: ', confusion_matrix(y_test, y_hat))
print ('')
print('The Jaccard Score is: ', jaccard_score(y_test, y_hat, average='micro')) # Change average to 'micro'
# Out:
# The Accuracy Score is:  0.71875
#
# The Confusion Matrix is:  [[103  27]
#  [ 27  35]]
#
# The Jaccard Score is:  0.5609756097560976
